# %%
import numpy as np

# %%
np.zeros(3)
np.zeros((2, 3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones(4)
# Out:
# array([1., 1., 1., 1.])

# %%
np.arange(1, 10, 2)   # [1 3 5 7 9]
# Out:
# array([1, 3, 5, 7, 9])

# %%
import numpy as np

a = np.array([10, 20, 30, 40])
print(a.shape)
# Out:
# (4,)

# %%
import numpy as np
a = np.array([1, 2, 3])
b = np.array([[1, 2], [3, 4]])
z = np.zeros((2, 3))

# %%
z
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
o = np.ones((3, 3))

# %%
o
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
r=np.arange(0,10,2)

# %%
r
# Out:
# array([0, 2, 4, 6, 8])

# %%
l=np.linspace(0,1,5)

# %%
l
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
print(a.shape)
# Out:
# (3,)

# %%
print(a.ndim)
# Out:
# 1

# %%
print(a.dtype)
# Out:
# int64

# %%
print(b[0, 1])
# Out:
# 2

# %%
print(r[1:4])
# Out:
# [2 4 6]

# %%
print(a+5)
# Out:
# [6 7 8]

# %%
print(a * 2)
# Out:
# [2 4 6]

# %%
   import numpy as np

a = np.array([1, 2, 3, 4])
b = np.array([10, 20, 30, 40])

print(a + b[0])
# Out:
# [11 12 13 14]

# %%
print(np.sum(a))
# Out:
# 10

# %%
print(np.mean(a))
# Out:
# 2.5

# %%
print(np.max(a))
# Out:
# 4

# %%
print(np.sqrt(a))
# Out:
# [1.         1.41421356 1.73205081 2.        ]

# %%
x=np.arange(6).reshape(2,3)

# %%
x
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
rand_arr = np.random.rand(2, 3)

# %%
rand_arr
# Out:
# array([[0.46194028, 0.60498315, 0.02217497],
#        [0.43220844, 0.49379078, 0.23946088]])

# %%
np.save('array_file.npy', a)

# %%
loaded=np.load('array_file.npy')

# %%
loaded
# Out:
# array([1, 2, 3, 4])
