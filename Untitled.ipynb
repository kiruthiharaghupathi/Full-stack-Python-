# %%
import pandas as pd

# %%
df = pd.read_csv("transport dataset.csv")

# %%
df.head()
# Out:
#    Vehicle_ID   Make_and_Model  Year_of_Manufacture Vehicle_Type  Usage_Hours  \
# 0           1       Ford F-150                 2022        Truck          530
# 1           2         Volvo FH                 2015          Van        10679
# 2           3  Chevy Silverado                 2022          Van         4181
# 3           4  Chevy Silverado                 2011        Truck         2974
# 4           5       Ford F-150                 2014          Van         2539
#
#   Route_Info  Load_Capacity  Actual_Load Last_Maintenance_Date  \
# 0      Rural       7.534549     9.004247            2023-04-09
# 1      Rural       7.671728     6.111785            2023-07-20
# 2      Rural       2.901159     3.006055            2023-03-17
# 3      Urban      15.893347    18.825290            2024-05-01
# 4      Rural      60.668320    65.605463            2023-11-15
#
#   Maintenance_Type  ...  Brake_Condition  Failure_History  Anomalies_Detected  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92000 entries, 0 to 91999
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Vehicle_ID             92000 non-null  int64
#  1   Make_and_Model         92000 non-null  object
#  2   Year_of_Manufacture    92000 non-null  int64
#  3   Vehicle_Type           92000 non-null  object
#  4   Usage_Hours            92000 non-null  int64
#  5   Route_Info             92000 non-null  object
#  6   Load_Capacity          92000 non-null  float64
#  7   Actual_Load            92000 non-null  float64
#  8   Last_Maintenance_Date  92000 non-null  object
#  9   Maintenance_Type       92000 non-null  object
#  10  Maintenance_Cost       92000 non-null  float64
#  11  Engine_Temperature     92000 non-null  float64
#  12  Tire_Pressure          92000 non-null  float64
#  13  Fuel_Consumption       92000 non-null  float64
# ...

# %%
df['Maintenance_Cost'].mean()
# Out:
# np.float64(1043.0047452242525)

# %%
df['Vehicle_Type'].value_counts()
# Out:
# Vehicle_Type
# Van      50850
# Truck    41150
# Name: count, dtype: int64

# %%
df.groupby('Vehicle_Type')['Maintenance_Cost'].mean()
# Out:
# Vehicle_Type
# Truck    1038.344005
# Van      1046.776416
# Name: Maintenance_Cost, dtype: float64

# %%
df[df['Fuel_Consumption'] > 15]
# Out:
#        Vehicle_ID   Make_and_Model  Year_of_Manufacture Vehicle_Type  \
# 5               6       Ford F-150                 2022          Van
# 9              10  Chevy Silverado                 2022        Truck
# 15             16       Ford F-150                 2020        Truck
# 19             20       Ford F-150                 2007        Truck
# 20             21  Chevy Silverado                 2021        Truck
# ...           ...              ...                  ...          ...
# 91975       91976  Chevy Silverado                 2010        Truck
# 91983       91984       Ford F-150                 2022        Truck
# 91984       91985       Tesla Semi                 2022        Truck
# 91985       91986       Ford F-150                 2020          Van
# 91989       91990  Chevy Silverado                 2021        Truck
#
#        Usage_Hours Route_Info  Load_Capacity  Actual_Load  \
# 5             2319      Urban       5.734597     4.897554
# ...

# %%
df[df['Vehicle_Type'] == 'Truck']
# Out:
#        Vehicle_ID   Make_and_Model  Year_of_Manufacture Vehicle_Type  \
# 0               1       Ford F-150                 2022        Truck
# 3               4  Chevy Silverado                 2011        Truck
# 7               8       Tesla Semi                 2021        Truck
# 8               9  Chevy Silverado                 2021        Truck
# 9              10  Chevy Silverado                 2022        Truck
# ...           ...              ...                  ...          ...
# 91989       91990  Chevy Silverado                 2021        Truck
# 91990       91991       Ford F-150                 2020        Truck
# 91993       91994  Chevy Silverado                 2007        Truck
# 91996       91997       Ford F-150                 2006        Truck
# 91998       91999       Tesla Semi                 2022        Truck
#
#        Usage_Hours Route_Info  Load_Capacity  Actual_Load  \
# 0              530      Rural       7.534549     9.004247
# ...

# %%
df[(df['Maintenance_Cost'] > 5000) & (df['Failure_History'] == 1)]
# Out:
#        Vehicle_ID   Make_and_Model  Year_of_Manufacture Vehicle_Type  \
# 10             11       Ford F-150                 2022          Van
# 60             61       Ford F-150                 2021        Truck
# 66             67       Ford F-150                 2021        Truck
# 83             84       Ford F-150                 2020          Van
# 84             85       Ford F-150                 2020        Truck
# ...           ...              ...                  ...          ...
# 91895       91896       Ford F-150                 2020          Van
# 91900       91901       Ford F-150                 2021        Truck
# 91920       91921       Ford F-150                 2022          Van
# 91936       91937  Chevy Silverado                 2022          Van
# 91969       91970       Tesla Semi                 2012          Van
#
#        Usage_Hours Route_Info  Load_Capacity  Actual_Load  \
# 10            3506    Highway       4.618450     5.154757
# ...

# %%
df.groupby('Route_Info')['Fuel_Consumption'].sum()
# Out:
# Route_Info
# Highway    490001.290307
# Rural      245973.284022
# Urban      244514.809011
# Name: Fuel_Consumption, dtype: float64

# %%
df['Brake_Condition'].replace('Bad', 'Poor')
# Out:
# 0        Good
# 1        Fair
# 2        Good
# 3        Good
# 4        Good
#          ...
# 91995    Fair
# 91996    Good
# 91997    Poor
# 91998    Poor
# 91999    Good
# Name: Brake_Condition, Length: 92000, dtype: object

# %%
df.drop_duplicates()
# Out:
#        Vehicle_ID   Make_and_Model  Year_of_Manufacture Vehicle_Type  \
# 0               1       Ford F-150                 2022        Truck
# 1               2         Volvo FH                 2015          Van
# 2               3  Chevy Silverado                 2022          Van
# 3               4  Chevy Silverado                 2011        Truck
# 4               5       Ford F-150                 2014          Van
# ...           ...              ...                  ...          ...
# 91995       91996  Chevy Silverado                 2022          Van
# 91996       91997       Ford F-150                 2006        Truck
# 91997       91998       Tesla Semi                 2020          Van
# 91998       91999       Tesla Semi                 2022        Truck
# 91999       92000       Ford F-150                 2020          Van
#
#        Usage_Hours Route_Info  Load_Capacity  Actual_Load  \
# 0              530      Rural       7.534549     9.004247
# ...

# %%
df['Vehicle_Type'].unique()
# Out:
# array(['Truck', 'Van'], dtype=object)

# %%
df.sort_values('Maintenance_Cost', ascending=False)
# Out:
#        Vehicle_ID   Make_and_Model  Year_of_Manufacture Vehicle_Type  \
# 66442       66443         Volvo FH                 2021          Van
# 27384       27385         Volvo FH                 2020          Van
# 78075       78076       Ford F-150                 2022          Van
# 52206       52207  Chevy Silverado                 2022        Truck
# 28145       28146       Ford F-150                 2011          Van
# ...           ...              ...                  ...          ...
# 63007       63008         Volvo FH                 2022          Van
# 55136       55137       Ford F-150                 2018          Van
# 68483       68484       Ford F-150                 2009          Van
# 2995         2996       Tesla Semi                 2022          Van
# 57898       57899       Ford F-150                 2021        Truck
#
#        Usage_Hours Route_Info  Load_Capacity  Actual_Load  \
# 66442         2845      Urban       6.931694     6.070625
# ...

# %%
df.sort_values('Maintenance_Cost', ascending=False)
# Out:
#        Vehicle_ID   Make_and_Model  Year_of_Manufacture Vehicle_Type  \
# 66442       66443         Volvo FH                 2021          Van
# 27384       27385         Volvo FH                 2020          Van
# 78075       78076       Ford F-150                 2022          Van
# 52206       52207  Chevy Silverado                 2022        Truck
# 28145       28146       Ford F-150                 2011          Van
# ...           ...              ...                  ...          ...
# 63007       63008         Volvo FH                 2022          Van
# 55136       55137       Ford F-150                 2018          Van
# 68483       68484       Ford F-150                 2009          Van
# 2995         2996       Tesla Semi                 2022          Van
# 57898       57899       Ford F-150                 2021        Truck
#
#        Usage_Hours Route_Info  Load_Capacity  Actual_Load  \
# 66442         2845      Urban       6.931694     6.070625
# ...

# %%
df['Vehicle_Type'].value_counts()
# Out:
# Vehicle_Type
# Van      50850
# Truck    41150
# Name: count, dtype: int64

# %%
df.drop('Route_Info', axis=1)
# Out:
#        Vehicle_ID   Make_and_Model  Year_of_Manufacture Vehicle_Type  \
# 0               1       Ford F-150                 2022        Truck
# 1               2         Volvo FH                 2015          Van
# 2               3  Chevy Silverado                 2022          Van
# 3               4  Chevy Silverado                 2011        Truck
# 4               5       Ford F-150                 2014          Van
# ...           ...              ...                  ...          ...
# 91995       91996  Chevy Silverado                 2022          Van
# 91996       91997       Ford F-150                 2006        Truck
# 91997       91998       Tesla Semi                 2020          Van
# 91998       91999       Tesla Semi                 2022        Truck
# 91999       92000       Ford F-150                 2020          Van
#
#        Usage_Hours  Load_Capacity  Actual_Load Last_Maintenance_Date  \
# ...

# %%
df.rename(columns={'Maintenance_Cost':'Cost'})
# Out:
#        Vehicle_ID   Make_and_Model  Year_of_Manufacture Vehicle_Type  \
# 0               1       Ford F-150                 2022        Truck
# 1               2         Volvo FH                 2015          Van
# 2               3  Chevy Silverado                 2022          Van
# 3               4  Chevy Silverado                 2011        Truck
# 4               5       Ford F-150                 2014          Van
# ...           ...              ...                  ...          ...
# 91995       91996  Chevy Silverado                 2022          Van
# 91996       91997       Ford F-150                 2006        Truck
# 91997       91998       Tesla Semi                 2020          Van
# 91998       91999       Tesla Semi                 2022        Truck
# 91999       92000       Ford F-150                 2020          Van
#
#        Usage_Hours Route_Info  Load_Capacity  Actual_Load  \
# 0              530      Rural       7.534549     9.004247
# ...

# %%
df.drop_duplicates()
# Out:
#        Vehicle_ID   Make_and_Model  Year_of_Manufacture Vehicle_Type  \
# 0               1       Ford F-150                 2022        Truck
# 1               2         Volvo FH                 2015          Van
# 2               3  Chevy Silverado                 2022          Van
# 3               4  Chevy Silverado                 2011        Truck
# 4               5       Ford F-150                 2014          Van
# ...           ...              ...                  ...          ...
# 91995       91996  Chevy Silverado                 2022          Van
# 91996       91997       Ford F-150                 2006        Truck
# 91997       91998       Tesla Semi                 2020          Van
# 91998       91999       Tesla Semi                 2022        Truck
# 91999       92000       Ford F-150                 2020          Van
#
#        Usage_Hours Route_Info  Load_Capacity  Actual_Load  \
# 0              530      Rural       7.534549     9.004247
# ...

# %%
df.sample(5)
# Out:
#        Vehicle_ID   Make_and_Model  Year_of_Manufacture Vehicle_Type  \
# 46689       46690       Tesla Semi                 2007        Truck
# 67503       67504       Ford F-150                 2009          Van
# 6259         6260       Ford F-150                 2020          Van
# 32325       32326  Chevy Silverado                 2015          Van
# 73463       73464       Ford F-150                 2022          Van
#
#        Usage_Hours Route_Info  Load_Capacity  Actual_Load  \
# 46689           91      Urban      67.863216    55.839093
# 67503         3508    Highway      16.035118    16.538936
# 6259          1818      Rural       6.597507     6.114193
# 32325          384    Highway       7.940567     9.181208
# 73463         6144    Highway      10.275498    11.036773
#
#       Last_Maintenance_Date Maintenance_Type  ...  Failure_History  \
# 46689            2024-02-05       Oil Change  ...                1
# ...

# %%
df.isnull().sum()
# Out:
# Vehicle_ID               0
# Make_and_Model           0
# Year_of_Manufacture      0
# Vehicle_Type             0
# Usage_Hours              0
# Route_Info               0
# Load_Capacity            0
# Actual_Load              0
# Last_Maintenance_Date    0
# Maintenance_Type         0
# Maintenance_Cost         0
# Engine_Temperature       0
# Tire_Pressure            0
# Fuel_Consumption         0
# Battery_Status           0
# Vibration_Levels         0
# Oil_Quality              0
# Brake_Condition          0
# Failure_History          0
# Anomalies_Detected       0
# Predictive_Score         0
# Maintenance_Required     0
# Weather_Conditions       0
# Road_Conditions          0
# Delivery_Times           0
# Downtime_Maintenance     0
# Impact_on_Efficiency     0
# Cost_per_Hour            0
# dtype: int64
